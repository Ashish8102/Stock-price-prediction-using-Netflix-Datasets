# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/archive.zip")

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000
# 1  2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000   11104800
# 2  2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143    6609400
# 3  2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571    6757800
# 4  2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429   10154200

# %%
df['Date']
# Out:
# 0       2002-05-23
# 1       2002-05-24
# 2       2002-05-28
# 3       2002-05-29
# 4       2002-05-30
#            ...
# 5039    2022-05-27
# 5040    2022-05-31
# 5041    2022-06-01
# 5042    2022-06-02
# 5043    2022-06-03
# Name: Date, Length: 5044, dtype: object

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['year']= df['Date'].dt.year
df['month']= df['Date'].dt.month
df['day']= df['Date'].dt.day

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2002-05-23    1.156429    1.242857    1.145714    1.196429    1.196429
# 1    2002-05-24    1.214286    1.225000    1.197143    1.210000    1.210000
# 2    2002-05-28    1.213571    1.232143    1.157143    1.157143    1.157143
# 3    2002-05-29    1.164286    1.164286    1.085714    1.103571    1.103571
# 4    2002-05-30    1.107857    1.107857    1.071429    1.071429    1.071429
# ...         ...         ...         ...         ...         ...         ...
# 5039 2022-05-27  193.190002  195.250000  190.369995  195.190002  195.190002
# 5040 2022-05-31  196.179993  199.949997  190.800003  197.440002  197.440002
# 5041 2022-06-01  198.699997  202.740005  191.660004  192.910004  192.910004
# 5042 2022-06-02  192.020004  205.470001  191.720001  205.089996  205.089996
# 5043 2022-06-03  200.139999  202.949997  198.050003  198.979996  198.979996
#
#          Volume  year  month  day
# 0     104790000  2002      5   23
# 1      11104800  2002      5   24
# 2       6609400  2002      5   28
# 3       6757800  2002      5   29
# 4      10154200  2002      5   30
# ...         ...   ...    ...  ...
# 5039    8586000  2022      5   27
# 5040   11398500  2022      5   31
# 5041    8416200  2022      6    1
# 5042    9623100  2022      6    2
# 5043    7181700  2022      6    3
#
# [5044 rows x 10 columns]

# %%
df.drop('Date',axis=1,inplace=True)

# %%
df.head()
# Out:
#        Open      High       Low     Close  Adj Close     Volume  year  month  \
# 0  1.156429  1.242857  1.145714  1.196429   1.196429  104790000  2002      5
# 1  1.214286  1.225000  1.197143  1.210000   1.210000   11104800  2002      5
# 2  1.213571  1.232143  1.157143  1.157143   1.157143    6609400  2002      5
# 3  1.164286  1.164286  1.085714  1.103571   1.103571    6757800  2002      5
# 4  1.107857  1.107857  1.071429  1.071429   1.071429   10154200  2002      5
#
#    day
# 0   23
# 1   24
# 2   28
# 3   29
# 4   30

# %%
df.shape
# Out:
# (5044, 9)

# %%
df.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# year         0
# month        0
# day          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5044 entries, 0 to 5043
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       5044 non-null   float64
#  1   High       5044 non-null   float64
#  2   Low        5044 non-null   float64
#  3   Close      5044 non-null   float64
#  4   Adj Close  5044 non-null   float64
#  5   Volume     5044 non-null   int64
#  6   year       5044 non-null   int32
#  7   month      5044 non-null   int32
#  8   day        5044 non-null   int32
# dtypes: float64(5), int32(3), int64(1)
# memory usage: 295.7 KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  5044.000000  5044.000000  5044.000000  5044.000000  5044.000000
# mean    116.467981   118.237392   114.578719   116.456338   116.456338
# std     168.740876   171.140864   166.119837   168.668232   168.668232
# min       0.377857     0.410714     0.346429     0.372857     0.372857
# 25%       3.955357     4.031072     3.885357     3.958571     3.958571
# 50%      25.819285    26.342143    25.455000    25.802856    25.802856
# 75%     155.762497   157.654998   153.944996   155.869999   155.869999
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume         year        month          day
# count  5.044000e+03  5044.000000  5044.000000  5044.000000
# mean   1.653068e+07  2011.905630     6.545797    15.737708
# std    1.924487e+07     5.798402     3.423809     8.758690
# min    2.856000e+05  2002.000000     1.000000     1.000000
# 25%    6.168225e+06  2007.000000     4.000000     8.000000
# 50%    1.059135e+07  2012.000000     7.000000    16.000000
# 75%    1.986552e+07  2017.000000    10.000000    23.000000
# max    3.234140e+08  2022.000000    12.000000    31.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #visualzing data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corr = df.corr()

# %%
corr
# Out:
#                Open      High       Low     Close  Adj Close    Volume  \
# Open       1.000000  0.999863  0.999853  0.999695   0.999695 -0.262560
# High       0.999863  1.000000  0.999815  0.999861   0.999861 -0.261281
# Low        0.999853  0.999815  1.000000  0.999856   0.999856 -0.264033
# Close      0.999695  0.999861  0.999856  1.000000   1.000000 -0.262548
# Adj Close  0.999695  0.999861  0.999856  1.000000   1.000000 -0.262548
# Volume    -0.262560 -0.261281 -0.264033 -0.262548  -0.262548  1.000000
# year       0.814140  0.814615  0.813706  0.814257   0.814257 -0.108797
# month     -0.004033 -0.004482 -0.003523 -0.004129  -0.004129 -0.044664
# day       -0.003739 -0.003833 -0.003572 -0.003773  -0.003773  0.032562
#
#                year     month       day
# Open       0.814140 -0.004033 -0.003739
# High       0.814615 -0.004482 -0.003833
# Low        0.813706 -0.003523 -0.003572
# Close      0.814257 -0.004129 -0.003773
# Adj Close  0.814257 -0.004129 -0.003773
# Volume    -0.108797 -0.044664  0.032562
# year       1.000000 -0.072108 -0.006204
# month     -0.072108  1.000000 -0.001500
# day       -0.006204 -0.001500  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm',cbar=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(x=df['Open'],y=df['Close'])
# Out:
# <Axes: xlabel='Open', ylabel='Close'>

# %%
sns.pairplot(df)

# %%
sns.distplot(df['Close'])
# Out:
# <ipython-input-220-400ee7bb7740>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Close'])
# <Axes: xlabel='Close', ylabel='Density'>

# %%
for i in df.columns:
  plt.figure(figsize=(10,6))
  sns.distplot(df[i])
  plt.title(i)
  plt.show()
# Out:
# <ipython-input-221-7add5c1037b9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-221-7add5c1037b9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-221-7add5c1037b9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-221-7add5c1037b9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-221-7add5c1037b9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-221-7add5c1037b9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-221-7add5c1037b9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-221-7add5c1037b9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-221-7add5c1037b9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])

# %% [markdown]
# # spilting data

# %%
x=df.drop('Close',axis=1)
y=df['Close']

# %%
x.shape
# Out:
# (5044, 8)

# %%
y.shape
# Out:
# (5044,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (3530, 8)

# %%
x_test.shape
# Out:
# (1514, 8)

# %%
x_train
# Out:
#             Open        High         Low   Adj Close    Volume  year  month  \
# 1271    3.002857    3.044286    2.841429    2.868571  40176500  2007      6
# 3555   94.699997   95.379997   93.180000   95.099998   9913500  2016      7
# 2436   13.242857   13.642857   13.092857   13.577143  77953400  2012      1
# 3968  294.769989  297.359985  290.589996  290.609985   9416500  2018      2
# 2021   15.991429   16.381430   15.701429   15.978571  18261600  2010      6
# ...          ...         ...         ...         ...       ...   ...    ...
# 1296    2.891429    2.891429    2.821429    2.874286   6498100  2007      7
# 365     4.099286    4.214286    4.085714    4.175000  14712600  2003     11
# 2964   64.417145   65.000000   63.655712   64.997147  12387900  2014      3
# 4259  374.489990  374.760010  365.700012  368.329987   6255500  2019      4
# 1499    4.385714    4.455714    4.285714    4.308571   6707400  2008      5
#
#       day
# 1271   12
# 3555    7
# 2436   25
# 3968   27
# 2021    3
# ...   ...
# 1296   18
# 365     3
# 2964    4
# 4259   25
# 1499    7
#
# [3530 rows x 8 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([261.429993,   2.442857,   2.484286, ..., 524.440002, 541.450012,
#          3.555   ])

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
r2_score(y_test,y_pred)
# Out:
# 1.0
